# %%
print("This is Notebook X")

# %%
df = spark.createDataFrame([("apple", 1), ("banana", 2)], ["fruit", "count"])
display(df)

# %%
df_count = df.count()
df_count

# %%
dbutils.jobs.taskValues.set(key="count", value=df_count)
