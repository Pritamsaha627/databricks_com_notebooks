# %% [markdown]
# # Time Travel In Delta Table

# %%
# %sql
SELECT * FROM deltatable_tutorial.demo.cust

# %%
# %sql
RESTORE TABLE deltatable_tutorial.demo.cust TO VERSION AS OF 2

# %%
# %sql
DESCRIBE HISTORY deltatable_tutorial.demo.cust

# %%
# %sql
SELECT * FROM deltatable_tutorial.demo.cust VERSION AS OF 2

# %%
df = spark.read.option('timestampAsOf','2026-01-17T16:50:15.000+00:00').table('deltatable_tutorial.demo.cust')
display(df)

# %%
display(spark.read.table('deltatable_tutorial.demo.cust@v3'))

# %%
# %sql
DELETE FROM deltatable_tutorial.demo.cust
WHERE c_custkey = 412450
